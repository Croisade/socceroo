# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['axes.grid'] = "True"
mpl.rcParams['axes.spines.top'] = "False"
mpl.rcParams['axes.spines.right'] = "False"
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20

df_mls = pd.read_csv("../../data/MLS_1823_stats.csv")
df_mls
# Out:
#     Unnamed: 0              team  shots  shots_ot   sca  gca   npxG     xA  \
# 0            0            Dynamo   1667       565  2945  288  177.8  119.0
# 1            1        Toronto FC   1540       561  2767  317  177.6  141.3
# 2            2         FC Dallas   1660       569  2913  293  179.5  113.9
# 3            3       Atlanta Utd   1660       581  3034  326  184.6  126.9
# 4            4         Nashville    724       272  1223  135   73.0   46.9
# 5            5       New England   1759       582  3094  325  185.3  131.7
# 6            6   Colorado Rapids   1553       516  2695  298  160.4   99.1
# 7            7       D.C. United   1469       482  2614  308  153.4  106.3
# 8            8      Philadelphia   1660       586  2923  338  183.7  138.2
# 9            9      Orlando City   1478       496  2603  307  160.0  125.8
# 10          10       Sporting KC   1841       617  3242  357  198.7  136.3
# ...

# %%
features = ["npxG","sca","gca","xA", "shots", "shots_ot"]

for feat in features:
    fig, ax = plt.subplots(figsize=(8,8))
    plt.scatter(df_mls[feat], df_mls.points, s=100, alpha=0.5, c='#2ECC71')
    ax.set_ylabel("Points", fontsize=30)
    ax.set_xlabel(feat.capitalize(), fontsize=30)
    plt.show()

# %%
from sklearn import linear_model

features = df_mls[["npxG","sca","gca","xA", "shots", "shots_ot"]]
target   = df_mls["points"]
regr = linear_model.LinearRegression(fit_intercept=False)
model = regr.fit(features, target)
model.score(features, target)
# Out:
# 0.861043359909146

# %%
from joblib import dump, load

dump(model, '../../data/mls_model.joblib')
# Out:
# ['../../data/mls_model.joblib']
