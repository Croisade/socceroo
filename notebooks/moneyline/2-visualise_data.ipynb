# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['axes.grid'] = "True"
mpl.rcParams['axes.spines.top'] = "False"
mpl.rcParams['axes.spines.right'] = "False"
mpl.rcParams['xtick.labelsize'] = 20
mpl.rcParams['ytick.labelsize'] = 20

df_mls = pd.read_csv("../../data/MLS_1823_clean.csv")
df_mls.head(29)
# Out:
#     Unnamed: 0                    Team  Season  npxG   SCA  GCA  GF   Sh  \
# 0            0             cf montreal    2018  39.9   717   80  47  418
# 1            1          houston dynamo    2018  53.7   825   96  58  470
# 2            2              toronto fc    2018  55.3   852   99  59  476
# 3            3               fc dallas    2018  52.8   849   90  52  477
# 4            4          atlanta united    2018  68.2   902  111  70  497
# 5            5  new england revolution    2018  43.0   810   81  49  481
# 6            6         colorado rapids    2018  36.4   637   58  36  375
# 7            7             d.c. united    2018  45.3   691  109  60  391
# 8            8      philadelphia union    2018  50.6   814   84  49  468
# 9            9            orlando city    2018  41.6   768   74  43  433
# 10          10    sporting kansas city    2018  59.3  1054  114  65  576
# 11          11            chicago fire    2018  36.1   601   82  48  337
# 12          12        seattle sounders    2018  41.7   746   86  52  425
# 13          13          real salt lake    2018  46.4   840   96  55  457
# 14          14               la galaxy    2018  50.9   755  124  66  420
# 15          15        portland timbers    2018  47.8   825   83  54  460
# 16          16    san jose earthquakes    2018  37.5   743   78  49  432
# 17          17           columbus crew    2018  48.5   884   75  43  490
# 18          18        minnesota united    2018  47.4   644   76  49  375
# 19          19          los angeles fc    2018  60.5   916  111  68  522
# 20          20            ny red bulls    2018  57.6   766  104  62  450
# 21          21                   nycfc    2018  54.6   918   93  59  529
# 22          22     vancouver whitecaps    2018  48.9   729   93  54  414
# 23          23    sporting kansas city    2019  54.5   856   82  49  490
# 24          24          houston dynamo    2019  48.8   796   83  49  450
# 25          25              toronto fc    2019  47.5   791   95  57  432
# 26          26               fc dallas    2019  47.0   815   83  54  465
# 27          27          atlanta united    2019  54.1   913   97  58  499
# 28          28  new england revolution    2019  52.0   801   91  50  448
#
#       xA  SoT  Pts
# 0   28.3  130   46
# 1   35.8  178   38
# 2   41.0  172   36
# 3   32.4  168   57
# 4   44.6  187   69
# 5   31.0  170   41
# 6   21.8  114   31
# 7   31.8  142   51
# 8   36.4  157   50
# 9   31.5  144   28
# 10  45.8  196   62
# 11  30.7  123   32
# 12  36.4  128   59
# 13  31.7  186   49
# 14  39.0  151   48
# 15  35.1  164   54
# 16  31.5  139   21
# 17  38.9  146   51
# 18  32.0  137   36
# 19  42.7  195   57
# 20  41.8  176   71
# 21  38.5  171   56
# 22  32.9  142   47
# 23  36.8  159   38
# 24  33.7  139   40
# 25  42.3  154   50
# 26  30.4  158   48
# 27  35.8  169   58
# 28  33.1  135   45

# %%
df_vancouver = df_mls[(df_mls["Season"] == 2022) & (df_mls["Team"] == "vancouver")]
df_vancouver.head(5)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Team, Season, npxG, SCA, GCA, GF, Sh, xA, SoT, Pts]
# Index: []

# %%
fig, ax = plt.subplots(figsize=(8,8))
plt.scatter(df_vancouver["Sh"], df_vancouver.GF, s=100, alpha=0.5, c='#2ECC71')
ax.set_ylabel("Goals", fontsize=30)
ax.set_xlabel("Shots", fontsize=30)
plt.show()
